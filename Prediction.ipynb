# %%
import numpy as np
import time

from mltu.tokenizers import CustomTokenizer
from mltu.inferenceModel import OnnxInferenceModel

class PtEnTranslator(OnnxInferenceModel):
    def __init__(self, *args, **kwargs):
        super().__init__(*args, **kwargs)

        self.new_inputs = self.model.get_inputs()
        self.tokenizer = CustomTokenizer.load(self.metadata["tokenizer"])
        self.detokenizer = CustomTokenizer.load(self.metadata["detokenizer"])

    def predict(self, sentence):
        start = time.time()
        tokenized_sentence = self.tokenizer.texts_to_sequences([sentence])[0]
        encoder_input = np.pad(tokenized_sentence, (0, self.tokenizer.max_length - len(tokenized_sentence)), constant_values=0).astype(np.int64)

        tokenized_results = [self.detokenizer.start_token_index]
        for index in range(self.detokenizer.max_length - 1):
            decoder_input = np.pad(tokenized_results, (0, self.detokenizer.max_length - len(tokenized_results)), constant_values=0).astype(np.int64)
            input_dict = {
                self.model._inputs_meta[0].name: np.expand_dims(encoder_input, axis=0),
                self.model._inputs_meta[1].name: np.expand_dims(decoder_input, axis=0),
            }
            preds = self.model.run(None, input_dict)[0] # preds shape (1, 206, 29110)
            pred_results = np.argmax(preds, axis=2)
            tokenized_results.append(pred_results[0][index])

            if tokenized_results[-1] == self.detokenizer.end_token_index:
                break
        
        results = self.detokenizer.detokenize([tokenized_results])
        return results[0], time.time() - start

def read_files(path):
    with open(path, "r", encoding="utf-8") as f:
        en_train_dataset = f.read().split("\n")[:-1]
    return en_train_dataset

# Path to dataset
en_validation_data_path = "Datasets/en-es/opus.en-es-dev.en"
es_validation_data_path = "Datasets/en-es/opus.en-es-dev.es"

en_validation_data = read_files(en_validation_data_path)
es_validation_data = read_files(es_validation_data_path)

# Consider only sentences with length <= 500
max_lenght = 500
val_examples = [[es_sentence, en_sentence] for es_sentence, en_sentence in zip(es_validation_data, en_validation_data) if len(es_sentence) <= max_lenght and len(en_sentence) <= max_lenght]

translator = PtEnTranslator("Models/09_translation_transformer/202501152112/model.onnx")

val_dataset = []
for es, en in val_examples:
    results, duration = translator.predict(es)
    print("Spanish:     ", es.lower())
    print("English:     ", en.lower())
    print("English pred:", results)
    print(duration)
    print()
# Out:
# Spanish:      no recuerdo por qué fue la pelea.
# English:      i don't even remember what the fight was about.
# English pred: i don't remember why it was the fight.
# 10.556736946105957
#
# Spanish:      estos son los sitios en que cada congreso ha tenido lugar:
# English:      here are the sites of each of those that have taken place:
# English pred: these are the places in which each congress has taken place:
# 16.510029792785645
#
# Spanish:      sí. soy el hombre que mató a barbanegra.
# English:      i'm the man who killed blackbeard.
# English pred: i'm the man who killed barbanegra.
# 9.047990798950195
#
# Spanish:      no te hagas el inteligente.
# English:      don't get smart.
# English pred: don't make the smart one.
# 6.83564019203186
#
# Spanish:      ¿existe un límite de cuándo se padece y cuándo no?
# English:      is there an exact moment in the life of a soldier before which he is not suffering from shell-shock and after which he is?
# English pred: is there a limit of when he suffers and when not?
# 13.52820348739624
#
# Spanish:      sí, joe.
# English:      yes, joe.
# English pred: yeah, joe.
# 2.8823962211608887
#
# Spanish:      ¿por qué dos meses?
# English:      why two months?
# English pred: why two months?
# 4.182665824890137
#
# Spanish:      no nos hace falta.
# English:      - we don't need the rock.
# English pred: we don't take care of that.
# 7.3401923179626465
#
# Spanish:      espero que a umeko se le pase lo de casarse con él.
# English:      i hope umeko will forget about marrying him.
# English pred: i hope umeko will have a marriage to him.
# 11.231032133102417
#
# Spanish:      ha dirigido varios proyectos y campañas en suiza y en el extranjero.
# English:      he has led several projects and campaigns in switzerland and abroad.
# English pred: he has addressed several projects and campaigns in switzerland and abroad.
# 19.509010791778564
#
# Spanish:      dicen que se casó con liz kelly.
# English:      said he went off and got hitched to liz kelly.
# English pred: they say he married liz kelly.
# 8.162275314331055
#
# Spanish:      establezcan un perímetro de dos cuadras alrededor de esta calle.
# English:      establish a 2-block perimeter around this block.
# English pred: they establish a two-block perimeter around this street.
# 18.465731859207153
#
# Spanish:      otros continúan identificándose como gay y lesbiana y participan en las comunidades gay y lesbiana a la vez que mantienen relaciones heterosexuales a largo plazo, incluso primarias (una opción aceptada por algunos y vista con sospecha por otras en las comunidades).
# English:      others continue to identify as lesbian or gay and take part in lesbian/gay communities even while having long-term—even primary—heterosexual relationships, a choice accepted by some and viewed suspiciously by others in their communities.
# English pred: others continue to identify as gay and lesbian and lesbian communities and lesbian are identified as they are long-term heterosexual relationships, even primary (a chosen option accepted by some and seen with suspect by other communities).
# 88.33249044418335
#
# Spanish:      todos nosotros tenemos que tener muy presente que los problemas con que se tiene que hacer frente en yugoslavia tienen unas raíces históricas muy profundas y son sumamente difíciles.
# English:      we all have to bear in mind that the problems that are being faced in yugoslavia are deep-rooted, historical problems and they are extremely difficult.
# English pred: we all have to be very present that the problems which have to be made according to yugoslavia have very deep historical roots and are extremely difficult.
# 51.43900728225708
#
# Spanish:      ese es el desgraciado que conozco y que amo.
# English:      now there's the bastard i know and love.
# English pred: that's the unfortunate i know and that i love.
# 15.178489446640015
#
# Spanish:      la rosa de la productividad de trabajo se levantó por un porcentaje similar durante este período. mientras tanto, el empleo guardó paso con el crecimiento demográfico.
# English:      labor productivity rose rose by a similar percentage during this period. meanwhile, employment kept pace with population growth.
# English pred: the rose of working productivity was risen by a similar percentage during this period. in the meantime, the employment stepped with demographic growth.
# 44.50973200798035
#
# Spanish:      ¿celulosa?
# English:      cellulose?
# English pred: cellulose?
# 3.6747374534606934
#
# Spanish:      hay un tipo de fascinación objetiva.
# English:      - then there's the objective kind of like fascination.
# English pred: there's a kind of objective fascination.
# 12.759340286254883
#
# Spanish:      me acostumbré a cómo los niños viven en downton, pero aún es extraño.
# English:      i'm used to the way the children live at downton, but it seems odd.
# English pred: i got used to how the kids live in downton, but it's still weird.
# 20.005109548568726
#
# Spanish:      http://www.quadkelten.de http://www.quadkelten.de/
# English:      http://www.dagev.de http://www.dagev.de/
# English pred: http://www.quadkelten.de http://www.quadkelten.de/
# 13.408284425735474
#
# Spanish:      podría ser agradable tener a un chico malo rizando esas plumas perfectas.
# English:      might be nice to have a bad boy ruffle those perfect feathers.
# English pred: it could be nice to have a bad boy riching those perfect feathers.
# 21.486515998840332
#
# Spanish:      ¿qué pasa?
# English:      - what's wrong with you ?
# English pred: what is it?
# 3.3212082386016846
#
# Spanish:      catherine. ¡oye!
# English:      catherine. hey!
# English pred: catherine. hey!
# 4.231435060501099
#
# Spanish:      veo que no es el caso .
# English:      i see that's not the case.
# English pred: i see it's not the case.
# 7.21902322769165
#
# Spanish:      - ¡ahora o nunca!
# English:      - now or never!
# English pred: - now or never!
# 4.919540882110596
#
# Spanish:      "declaro las olimpiadas inauguradas!".
# English:      that i declare the olympics open!
# English pred: "i say the olympics opened!"
# 9.122241020202637
#
# Spanish:      en muchos aspectos, sus grabaciones para nuevos medios aún no han sido superadas.
# English:      in many aspects there haven't been any other recordings better than the ones la barbería made with nuevos medios.
# English pred: in many aspects, their recordings for new means have not yet been overcome.
# 23.069968223571777
#
# Spanish:      conviene complementar el procedimiento de supervisión multilateral a que se refiere el artículo 121, apartados 3 y 4, del tfue con normas específicas para la detección de los desequilibrios macroeconómicos, así como para la prevención y corrección de desequilibrios macroeconómicos excesivos dentro de la unión.
# English:      it is appropriate to supplement the multilateral surveillance procedure referred to in paragraphs 3 and 4 of article 121 tfeu with specific rules for the detection of macroeconomic imbalances as well as the prevention and correction of excessive macroeconomic imbalances within the union.
# English pred: it should be supplemented by the multilateral monitoring procedure referred to in article 121(3) and (4) of the tfe was specific standards for the detection of macroeconomic imbalances, as well as for the prevention and correction of excessive macroeconomic imbalances within the union.
# 86.7310152053833
#
# Spanish:      comisión de la verdad y la reconciliación 53 - 59 16
# English:      the truth and reconciliation commission 53 - 59 15
# English pred: truth and reconciliation 53 - 59 16
# 12.318581342697144
#
# Spanish:      santuario, nicky.
# English:      sanctuary, nicky.
# English pred: sanctuary, nicky.
# 5.2333009243011475
#
# Spanish:      no cuando yo tengo todos los naipes.
# English:      not when i hold all the cards.
# English pred: not when i have every naipe.
# 8.249101400375366
#
# Spanish:      está preocupado.
# English:      he's kind of worried.
# English pred: it's worried.
# 4.0696892738342285
#
# Spanish:      - estoy listo, bob.
# English:      - i'm ready, bob. - do it!
# English pred: - i'm ready, bob.
# 5.143279790878296
#
# Spanish:      creo que necesita un poco de tiempo por a sí mismo.
# English:      i think he needs a little time by himself.
# English pred: i think he needs a little time for himself.
# 20.378063678741455
#
# Spanish:      tenemos que cambiar rostros quirúrgicamente para poderme hacer pasar por ti y ganarme su corazón.
# English:      we need to surgically switch faces, so i can pretend to be you and win her heart.
# English pred: we have to change faces surgically so we can make me go through you and win my heart.
# 31.376479625701904
#
# Spanish:      en un debate parlamentario en nueva zelanda en relación con las importaciones de fosfatos del sahara occidental el 26 de julio de 2006, mencionó que era consciente de la opinión de naciones unidas desde 2002, y afirmó que los intereses de los territorios no autónomos deben ser primordiales en esta cuestión al examinar la legalidad de dichas importaciones.
# English:      in a new zealand parliamentary debate regarding the new zealand phosphate imports from western sahara on july 26th 2006, you mentioned that you were indeed aware of the un opinion from 2002, stating that the interests of the inhabitants of non-self governing territories must be paramount in such an issue when considering the legality of such imports.
# English pred: in a parliamentary debate in new zealand in relation to the imports of western sahara on 26 july 2006, he mentioned that it was aware of the united nations opinion since 2002, and said that the interests of non-self-governing territories should be primary in this issue in considering the legality of these imports.
# 107.21353054046631
#
# Spanish:      - pero hablemos de otra cosa.
# English:      let's change the subject...
# English pred: - but let's talk about something else.
# 11.042163133621216
#
# Spanish:      ¿vas a rechazar un trabajo de verdad solo para estar en una pequeña obra de la escuela?
# English:      you're gonna turn down a job in a real music video. just to be in some little play here at school?
# English pred: are you gonna reject a real job just to be in a small work of school?
# 23.570531129837036
#
# Spanish:      ¿pero cuánto es realmente lo que vale?
# English:      but how much is that really worth?
# English pred: but how much is it really worth what?
# 10.66582703590393
#
# Spanish:      ¿tú crees?
# English:      - you think? - yes.
# English pred: you think?
# 2.9431912899017334
#
# Spanish:      ¡vete a tú habitación y piensa en toda la cantidad de juguetes que tienes!
# English:      go to your room and think about all the toys you've got!
# English pred: go to your room and think about the whole quantity of toys you have!
# 18.48378825187683
#
# Spanish:      pensé que éste era el baño.
# English:      - i thought this was the bathroom.
# English pred: i thought this was the bathroom.
# 8.944270372390747
#
# Spanish:      la correlación anatómica-ecocardiográfica fue precisa y permitió un mejor conocimiento de esta anomalía.
# English:      the anatomoechocardiographic correlation was precise and allowed a better understanding of this anomaly.
# English pred: anatomic correlation - ecocardiographic was accurate and allowed better knowledge of this anomaly.
# 32.82766366004944
#
# Spanish:      por eso no pude permitir que te ahogaras en el fondo del lago reiden por eso era necesario permitir que el otro doctor bishop lograra curarte.
# English:      it was why i could not allow you to drown at the bottom of reiden lake. why it was necessary to allow the other dr. bishop to cure you instead.
# English pred: that's why i couldn't allow you to drown in the lake reiden bottom for that need to allow the other dr. bishop to make you cure yourself.
# 37.95268392562866
#
# Spanish:      ¡yo tomaré las tijeras, joe!
# English:      i'll get the scissors, joe!
# English pred: i'll take the scissors, joe!
# 7.868993520736694
#
# Spanish:      -con otros niños, hace varios meses. ¿qué te pasa?
# English:      with other children, a few months ago ?
# English pred: - with other kids, several months ago. what's wrong with you?
# 17.73350715637207
#
# Spanish:      de manera contraria al arte marroquí moderno mayoritario, bajo la presión de ajustarse a ciertos estándares, el arte independiente en darija rompe fronteras con blasfemias y jerga, se centra en temas muy polémicos y experimenta con estilos distintos.
# English:      unlike modern mainstream moroccan art, which is under pressure to conform to certain standards, independent art in darija pushes boundaries, using profanity and slang, touching on highly controversial themes, and experimenting with different styles.
# English pred: contrary to the modern moroccan art modern modern art, under the pressure of adjusting to certain standards, the independent art in darija broken breaking blasphemias and jerga, focuses on very many polemic and experiments with different styles.
# 80.35127520561218
#
# Spanish:      tenga a la mano su número de tarjeta de identificación de peach state. el(la) enfermero(a) lo(a) puede dirigir a otro tipo de atención médica. o puede ayudarle por teléfono.
# English:      the nurse may direct you to other care. or the nurse may help you over the phone.
# English pred: hand your peach state identification card number (a) lo(a) can direct another medical card. or you can help you on the phone.
# 38.80644345283508
#
# Spanish:      ¿en serio?
# English:      really?
# English pred: have we?
# 2.7342300415039062
#
# Spanish:      ¿dónde fué eso, en florencia?
# English:      where was that, in florence?
# English pred: where did that go, in florence?
# 9.281017541885376
#
# Spanish:      - ahora mismo les aviso.
# English:      - i'll call this now.
# English pred: - right now i warn you.
# 6.793008804321289
#
# Spanish:      bueno, de hecho fue en la conferencia de copenhague.
# English:      well actually that was the conference at copenhagen
# English pred: well, it was actually at the copenhagen conference.
# 18.611379384994507
#
# Spanish:      todavía te puedo ver como un bebé, pegado de la teta de tu mamá, con determinación.
# English:      i can still see you as a baby, sucking on your mother's tit, with fierce determination.
# English pred: i can see you as a baby, sticking on your mom's tit, with determination.
# 21.94806933403015
#
# Spanish:      sé que he estado sobre tu caso, pero la verdad es que has hecho que todo esto sea posible.
# English:      i know i've been on your case, but the truth is, you made this all happen.
# English pred: i know i've been about your case, but the truth is that you made this all possible.
# 24.527344703674316
#
# Spanish:      verás que somos el uno para el otro.
# English:      you'll see that we belong together.
# English pred: you'll see we're the one for each other.
# 14.02438735961914
#
# Spanish:      se pierde en las páginas del tiempo de la humanidad el origen de la cremación. las antiguas civilizaciones la realizaban respetando sus respectivas costumbres y creencias.
# English:      the origins of cremation cannot be traced back in the history of mankind. ancient civilizations performed it respecting their own customs and beliefs.
# English pred: it loses the pages of the time of humanity the cremation origin. former civilizations were conducting their respective customs and beliefs.
# 47.080145597457886
#
# Spanish:      mi excusa es el vodka.
# English:      mine's vodka.
# English pred: my excuse is the vodka.
# 7.777833938598633
#
# Spanish:      esta noche los estamos ofreciendo una de piezas favoritas de patrick godureaux :
# English:      tonight we're offering you one of patrick godureaux's favorite pieces:
# English pred: tonight we are offering them one of favorite pieces from patrick godureaux :
# 22.78301692008972
#
# Spanish:      manteniendo nuestra política editorial, nos reservamos el derecho a eliminar comentarios que consideremos inapropiados, pero todas las voces civiles serán escuchadas y todas las opiniones, respetadas.
# English:      in keeping with our editorial policies, we reserve the right to excise comments that we deem inappropriate, but all civil voices will be heard, all opinions respected.
# English pred: keeping our editorial policy, we reserve the right to eliminate comments we will consider inappropriate, but all civilian voices will be heard and all the views, respected.
# 53.46985864639282
#
# Spanish:      ¡yo sigo viajando y espero llegar a un destino alguna vez!
# English:      i am still travelling and hope to reach a destination sometime!
# English pred: i keep traveling and i hope to get to a fate ever!
# 14.458675384521484
#
# Spanish:      hay que añadir los honorarios del sr. rummschüttel.
# English:      rummschuettei will have to be paid if he remains our doctor.
# English pred: mr. rummschüttel's financials need to be added.
# 14.042620658874512
#
# Spanish:      qué mostraba la imagen de nasa, y por qué esta imagen fue retenida de la mirada pública?
# English:      what did nasa image and why is this image being withheld from public view?
# English pred: what showed the image of nasa, and why this image was retained from the public look?
# 24.24332070350647
#
# Spanish:      el consejo de seguridad se reúne de conformidad con el entendimiento alcanzado en sus consultas previas.
# English:      the council is meeting in accordance with the understanding reached in the course of its prior consultations.
# English pred: the security council is meeting in accordance with the understanding reached in its previous consultations.
# 31.46432638168335
#
# Spanish:      habla lennox.
# English:      this is lennox.
# English pred: this is lennox.
# 4.426614761352539
#
# Spanish:      sí, usted ha dicho que, ma apos; am.
# English:      yes, you said that, ma'am.
# English pred: yeah, you said that, ma apos; am.
# 9.648935079574585
#
# Spanish:      la escalera de vuestra nación no va hacia arriba; va hacia abajo. - nuestra señora, 7 de diciembre, 1971
# English:      the ladder from your country is not going up; it is going down." - our lady, december 7, 1971
# English pred: the stairs of your nation is not going upstairs; it goes downstairs. - our lady, 7 december, 1971
# 31.541734218597412
#
# Spanish:      la junta consideró hasta qué punto los estados financieros se ajustaban a las normas contables del sistema de las naciones unidas.
# English:      the board assessed the extent to which the financial statements conformed to the united nations system accounting standards.
# English pred: the board considered how financial statements adjusted the accounting standards of the united nations system.
# 33.13304948806763
#
# Spanish:      http://theeworld.blogspot.com.es/
# English:      http://theeworld.blogspot.com.es/
# English pred: http://theeworld.blogspot.com/
# 9.976515293121338
#
# Spanish:      h 12 residuos que emiten gases tóxicos o muy tóxicos al entrar en contacto con el aire, con el agua o con un ácido.
# English:      h 12 waste which releases toxic or very toxic gases in contact with water, air or an acid.
# English pred: h 12 waste that issue toxic or toxic gases when they come into contact with the air, with water or an acid.
# 33.08295130729675
#
# Spanish:      ¿qué me dice del sello calidad para los alimentos no manipulados genéticamente?
# English:      what of a stamp of quality for foodstuffs free from genetic modification?
# English pred: what does the seal say for unmanipulated foods genetically?
# 19.674968004226685
#
# Spanish:      es una mezcla de poliéster y poliolefina, como el que encuentras en el maletero de un auto.
# English:      it's a polyester and polyolefin blend, like what you'd find in the trunk of a car.
# English pred: it's a mixture of polyester and polyolefine, like the one you find in the trunk of a car.
# 26.788830757141113
#
# Spanish:      bien, ¿qué, qué, qué estás pensando?
# English:      okay, what, what, what are you thinking?
# English pred: well, what, what, what are you thinking?
# 12.09709095954895
#
# Spanish:      dorada (2) correa
# English:      mens wristwatch (2)
# English pred: dorada (2) run
# 4.32776403427124
#
# Spanish:      todavía está con richard.
# English:      - he doesn't want to be interrupted.
# English pred: she's still with richard.
# 7.632061719894409
#
# Spanish:      larry, ...no puedes algo así en secreto.
# English:      larry you can't keep on carrying a secret like that.
# English pred: larry, you can't something like that in secret.
# 14.714333057403564
#
# Spanish:      hasta que entendí que no era más que un sueño.
# English:      until i realized it was just a dream.
# English pred: until i understood it was just a dream anymore.
# 13.999702215194702
#
# Spanish:      esto da un total de 132 paquetes huérfanos.
# English:      this makes a total of 192 orphaned packages.
# English pred: this gives a total of 132 orphan packages.
# 12.970134735107422
#
# Spanish:      cada capítulo de la saga gira en torno de un meteorito específico, de los muchos desenterrados, perdidos o todavía por descubrir en el suelo chaqueño.
# English:      each chapter of the saga revolves around one specific meteorite, of the many buried, lost or still to be discovered in the chaqueño soil.
# English pred: each chapter of the saga turns around a specific meteorite, of many disentered, lost or still to find out on the sweaty soil.
# 38.96349263191223
#
# Spanish:      - eso sí que fue rápido.
# English:      whoa! that was crazy fast.
# English pred: - that was quick.
# 5.6303746700286865
#
# Spanish:      ha escuchado el crujir de las hojas.
# English:      have you heard the rustling of the leaves.
# English pred: he heard the leave cross.
# 8.74896240234375
#
# Spanish:      solo tengo un disparo.
# English:      i only have this one shot.
# English pred: i just have one shot.
# 6.975952625274658
#
# Spanish:      ella está aquí por una razón diferente.
# English:      she's, uh, she's here for a different reason. it doesn't matter.
# English pred: she's here for a different reason.
# 10.397427320480347
#
# Spanish:      a veces pienso que la escuela de postgrado es un extraño experimento sicológico
# English:      sometimes i think grad school's just a weird psychological experiment.
# English pred: sometimes i think postgrad school is a strange experiment of psychological experiment
# 25.114425659179688
#
# Spanish:      trabaja aquí al lado.
# English:      he works nearby.
# English pred: he works here next to the side.
# 9.090349197387695
#
# Spanish:      ¡vaya! bien. bien, bien, bien, bien...
# English:      well... well,well,well,well,well.
# English pred: okay, okay, okay, okay, well...
# 10.316376447677612
#
# Spanish:      compromisos de los participantes
# English:      undertakings by participants
# English pred: commitments of participants
# 8.873523712158203
#
# Spanish:      - ¿no te tomarás nada?
# English:      - won't you have something?
# English pred: - you won't take anything?
# 7.891997337341309
#
# Spanish:      permíteme... - ¡no!
# English:      let me -- no!
# English pred: let me...
# 2.969034194946289
#
# Spanish:      sólo fue una estúpida... fiesta de cuentos de hadas.
# English:      it was just some stupid... fairy-tale rave.
# English pred: it was just a stupid party of fairy tales.
# 12.372979640960693
#
# Spanish:      muy bien, si ud. io dice...
# English:      very well. if you say so.
# English pred: all right, if you say it...
# 7.993453025817871
#
# Spanish:      ¿necesitas atención médica o algo?
# English:      need some medical attention or something?
# English pred: you need medical care or something?
# 10.36431360244751
#
# Spanish:      y ya falleció, por lo que debo seguir cumpliéndolo.
# English:      and now he's dead, so i'm stuck with my vow.
# English pred: and he already died, so i should keep it fulfilling.
# 15.957960367202759
#
# Spanish:      según los estudios, los dibujos pertenecen al periodo magdaleniense y, por tanto, tienen más de 13.000 años . están hechos con tinta negra.
# English:      according to studies, the paintings go back to the magdalenian period, and thus they are over 13.000 years old. they were made using black ink .
# English pred: according to studies, drawings belong to the magdaleniense period and therefore have more than 13,000 years old. they are made with black shop.
# 41.55934524536133
#
# Spanish:      son puertas del nivel de seguridad 8.
# English:      that' s a level- eight security door.
# English pred: they're doors of the security level 8.
# 11.469237804412842
#
# Spanish:      o acerca de algo en absoluto.
# English:      about anything at all.
# English pred: or about something at all.
# 7.862847328186035
#
# Spanish:      klaus me salvó la vida.
# English:      klaus saved my life.
# English pred: klaus saved my life.
# 5.928204298019409
#
# Spanish:      era el puente constituido por las mismas almas, el puente que un día tendría que estar tendido entre el más allá y esta tierra, entre lo conocido y lo desconocido.
# English:      it was the bridge constituted by the very souls –a bridge that one day should be tended between the beyond and this earth, between known and unknown.
# English pred: it was the bridge constituted by the same souls, the bridge that one day would have to be started between the beyond and this earth, between the unknown and unknown.
# 48.67087411880493
#
# Spanish:      la sonata para violín n.º 36 en fa mayor, k. 547, fue completada el 10 de julio de 1788 por wolfgang amadeus mozart.
# English:      the sonata in f for violin and keyboard, k. 547, was completed on july 10, 1788 by wolfgang amadeus mozart.
# English pred: the sonate for violin n. 36 in fa major, k. 547, was completed on 10 july 1788 by wolfgang amadeus mozart.
# 29.46897792816162
#
# Spanish:      en cuanto al objetivo de participación en el proceso de paz de oriente próximo, ¿cómo no podemos tener dudas al enterarnos de que antes de ayer gran bretaña participó unilateralmente, junto con los estados unidos, en una huelga aérea, otra, contra iraq, el mismo día en que llegaron allí los inspectores establecidos en la resolución 1 441 l?
# English:      as for the objective of participating in the middle east peace process, how can we fail to have doubts when we learn that the day before yesterday, great britain participated unilaterally, together with the united states of america, in an air strike - yet another - against iraq, the very day on which the inspectors stipulated in resolution 1441 arrived there?
# English pred: as for the participation objective in the next east peace process, how can we not have doubts to enter us before britain has used a large britain participated only together with the united states, in another air strike, against iraq, the same day when the inspectors laid down in resolution 1441 l?
# 86.03744268417358
#
# Spanish:      voy a ir a liverpool y descubrir a los beatles.
# English:      i'm going to go to liverpool and discover the beatles.
# English pred: i'm going to liverpool and find out the beatles.
# 14.258711814880371
#
# Spanish:      # ¡te haré gritar! #
# English:      ♪ i'm gonna make you scream ooh!
# English pred: ♪ i'll make you scream!
# 6.448323726654053
#
# Spanish:      sólo nos interrumpirá nuestro trabajo.
# English:      you can only keep us from our work.
# English pred: just interrupt us our job.
# 7.509030818939209
#
# Spanish:      ¿qué pasa, señora?
# English:      madam, what's wrong?
# English pred: what's up, ma'am?
# 5.189090013504028
#
# Spanish:      vamos, gordo.
# English:      let's go, big.
# English pred: come on, fat.
# 3.8583312034606934
#
# Spanish:      sabes, has... estado raro desde que volvimos.
# English:      you know, you've... been weird ever since we got back.
# English pred: you know, you've... weird since we came back.
# 13.097596645355225
#
# Spanish:      - me gustaría preguntarle algo.
# English:      - i'd iike to ask you something
# English pred: - i'd like to ask you something.
# 9.361506223678589
#
# Spanish:      carmen te enseñará la salida.
# English:      you can have carmen show you out.
# English pred: carmen will show you the way out.
# 13.503368139266968
#
# Spanish:      volveré en una semana a ver cómo estás.
# English:      i'll be back in a week to check on you.
# English pred: i'll be a week back to see how you are.
# 12.841837167739868
#
# Spanish:      comenzó poniéndome enfermo.
# English:      it started with getting me sick.
# English pred: she started getting sick.
# 8.097094535827637
#
# Spanish:      la información del gps del coche de henry.
# English:      the gps data from henry's car.
# English pred: the information on the henry car confidence.
# 12.326746463775635
#
# Spanish:      ¿hola?
# English:      hello?
# English pred: hello.
# 1.8781707286834717
#
# Spanish:      - tú empiezas. - vale.
# English:      you speak first, then.
# English pred: - you start.
# 3.6239213943481445
#
# Spanish:      compuesta por los miembros antes mencionados,
# English:      composed as above,
# English pred: consistent of members before mentioned,
# 11.017514705657959
#
# Spanish:      pero entonces los estados dijeron,
# English:      the states, of course, said, "hey!
# English pred: but then states said,
# 5.913026809692383
#
# Spanish:      este fue el tema del año internacional de las personas de edad (1999) y posteriormente se convirtió en uno de los principios fundamentales del plan de acción internacional de madrid sobre el envejecimiento (2002), aprobado durante la segunda asamblea mundial sobre el envejecimiento.
# English:      this concept was adopted as the theme for the international year of older persons in 1999 and subsequently became a central tenet of the madrid international plan of action on ageing 2002, adopted at the second world assembly on ageing.
# English pred: this was the international year of the persons of age (1999) and subsequently became one of the fundamental principles of the international madrid action plan on ageing (2002), adopted during the second world assembly on ageing.
# 62.622044801712036
#
# Spanish:      ¿no hubo una nueva llamada de los terroristas?
# English:      there's been no follow-up phone call from the terrorists?
# English pred: there wasn't a new call from terrorists?
# 11.078212976455688
#
# Spanish:      en el organo legislativo no ha habido un esfuerzo sistemático de parte del frente por solidificar su ventajosa posición opositora.
# English:      in the legislative assembly the fmln has not made a systematic effort to consolidate its advantageous position as the opposition.
# English pred: in the legislative body there has been no systematic effort of the front to solidify its advantageous opposition.
# 31.226256608963013
#
# Spanish:      así que creeme cuando te digo si no dejas y desiste de difamar su buen nombre y el buen nombre de este hospital reuniré todos los recursos de esta institución y te llevaré ante un juzgado y seguro que tu y tus sueños
# English:      so i hope you believe me when i tell you that if you do not cease and desist with this slandering of his good name and the good name of this hospital, i will marshal all the resources of this institution and take you to court and make sure that yu and your dreams... never defame anyone again.
# English pred: so believe me when i tell you when i say if you don't let you desist your good name and the good name of this hospital, i will gather all the resources of this institution and i'll take you to a court and sure that you and your dreams
# 66.266685962677
#
# Spanish:      oye, ¿sabes lo que estaba pensando?
# English:      hey, you know what i was thinking?
# English pred: hey, you know what i was thinking?
# 10.200576543807983
#
# Spanish:      ¿hay grandes cantidades de humo, negro o blanco se omiten?
# English:      are there large quantities of smoke, black or white being omitted?
# English pred: is there great quantities of smoke, black or white omit?
# 15.592754364013672
#
# Spanish:      c) transporte local, seguridad, comunicaciones y gastos diversos durante las misiones sobre el terreno (7.200 dólares).
# English:      (b) requested the president of the council and the united nations high commissioner for human rights to report to the council at its fifth session on their efforts for the implementation of council resolutions s-1/1 and s-3/1 and on the compliance of israel, the occupying power, with these two resolutions.
# English pred: (c) local transport, security, communications and costs during the field missions ($7,200).
# 25.22869086265564
#
# Spanish:      - ya vuelvo.
# English:      - i' il be right back.
# English pred: - i'll be right back.
# 5.915689945220947
#
# Spanish:      actualmente, tenemos más de 38,0000 sectas cristianas no-católicas.¿no son estas 38,000+ "piezas"?.
# English:      today, we have 38,000+ non-catholic christian sects. aren't they 38,000+'pieces'.
# English pred: we currently have more than 38,000 non-catholic christian sects. aren't this 38,000 % pieces?"
# 25.757561206817627
#
# Spanish:      b) servicios sociales que permitan a las personas mayores y a las personas con discapacidad permanecer en su entorno de vida habitual el mayor tiempo posiblej y recibir una asistencia sanitaria y social adecuada cuando son dependientes.
# English:      (b) social services that enable older persons and persons with disabilities to remain in their normal living environment for as long as possible and to receive adequate health and social care when they are dependent.
# English pred: (b) social services that allow people to be older and disabilities to remain in their usual life environment as possible as long as possible and receive appropriate health and social assistance when they are dependent.
# 60.76036071777344
#
# Spanish:      a pesar del riesgo del adulterio, se sabe que se le va a ofrecer.
# English:      despite the risk of committing adultery. david knew she would offer herself to him.
# English pred: despite the risk of the adultery, it is known that he will offer.
# 18.21569585800171
#
# Spanish:      una docena de cosas podrían explicar la correlación.
# English:      a dozen things could account for the correlation.
# English pred: a dozen things could explain correlation.
# 11.414616823196411
#
# Spanish:      ¿por qué mi permanente wimpernwelle ha durado sólo una semana?
# English:      my lash lifting by wimpernwelle eyelash perm only lasted for one week!
# English pred: why did my permanent wimpernwelle lasted only one week?
# 15.357919692993164
#
# Spanish:      el comité estima que la organización debe seguir siendo custodia de la legitimidad internacional y desempeñar un papel clave en la movilización de la asistencia internacional para el desarrollo, dada la importancia de esa asistencia para el proceso de paz.
# English:      the committee believes that the organization should remain the guardian of international legitimacy and play a key role in mobilizing international assistance for development, given the importance of such assistance to the peace process.
# English pred: the committee estimates that the organization should remain custody of international legitimacy and play a key role in the mobilization of international development assistance, given the importance of this peace assistance.
# 62.09882187843323
#
# Spanish:      como es habitual desde 2005, en caso de caã da en los ãºltimos tres kilã³metros, los corredores implicados recibirã¡n el tiempo del grupo al que pertenecen.
# English:      as has been the case since 2005, riders involved in a fall in the last three kilometres of a stage are given the same finishing time as the group which they belonged to.
# English pred: as a route in 2005, if the last three miles are involved, the corridors will be received by the time of the group belonging to.
# 35.17478680610657
#
# Spanish:      la televisión nacional transmitió un programa en el que se enunciaban detalladamente los objetivos y se difundían entrevistas con el presidente, funcionarios superiores del gobierno, y el coordinador residente.
# English:      a programme spelling out each goal and including interviews with the president, senior government officials and the resident coordinator was broadcast on national television.
# English pred: the national tv transmitted a programme where the objectives were detailed and disseminated interviewed with the president, higher officials of the government, and the resident coordinator.
# 52.52949595451355
#
# Spanish:      complejo termal (1)
# English:      hot spring resort (1)
# English pred: complex termal (1)
# 5.203646421432495
#
# Spanish:      (2) es preciso incorporar al acuerdo la decisión 98/377/ce de la comisión, de 18 de mayo de 1998, por la que se adapta el anexo i del reglamento (cee) n° 571/88 del consejo relativo a la organización de las encuestas comunitarias sobre la estructura de las explotaciones agrícolas(2).
# English:      (2) commission decision 98/377/ec of 18 may 1998 adapting annex i to council regulation (eec) no 571/88 in view of the organisation of the community surveys on the structure of agricultural holdings(2) is to be incorporated into the agreement,
# English pred: (2) commission decision 98/377/ec of 18 may 1998 adapting annex i to council regulation (eec) no 571/88 on the organization of community surveys on the structure of agricultural exploitations (2).
# 54.167248249053955
#
# Spanish:      ¿cómo está tu hijo?
# English:      how's your baby?
# English pred: how's your son?
# 4.364922523498535
#
# Spanish:      - las cantidades de azúcar blanco producido y el importe global de la ayuda específica para la transformación abonado.
# English:      - of the quantities of white sugar produced and the overall amount of the special processing aid paid;
# English pred: - the quantities of white sugar produced and the overall amount of specific aid for transformation abondated.
# 30.30672597885132
#
# Spanish:      "de acuerdo con la teoría clásica de los cuatro humores, los hombres se pensaba que eran calurosos y secos, lo cual era bueno.
# English:      'according to the classical theory of the four humours, 'men were thought to be hot and dry, which was good.
# English pred: "according to the classical theory of four moods, men thought they were hot and dry, which was good.
# 28.28950834274292
#
# Spanish:      oh, mary, qué imagen espantosa... una borracha amargada que describe un tórrido romance... mientras te da de comer bananas en tu sillita de bebé. bueno, tenía 9 años.
# English:      oh, mary, what an awful picture-- a bitter old drunk describing some tawdry affair while spoon-feeding you strained bananas as you sit in your little highchair.
# English pred: oh, mary, what spantous image... a drunk drunk that describes a romance torrid... while you get your bananas in your baby shirt.
# 35.667333364486694
#
# Spanish:      les sugieron que lo mediten.
# English:      i strongly suggest you think it over.
# English pred: they suggested them to meditate it.
# 10.086143016815186
#
# Spanish:      vas a conservar al asiento, en tres.
# English:      you're gonna hold on to that seat, on three.
# English pred: you're gonna store the seat, in three.
# 10.764781713485718
#
# Spanish:      ese es el chico que le gano a nathan?
# English:      so that's the boy that beat nathan?
# English pred: that's the boy i hand nathan?
# 8.803159236907959
#
# Spanish:      la secundaria apestó. dustin cooper estudiante de honor, secundaria silverton.
# English:      high school sucked.
# English pred: secondary sucked. dustin cooper student of honor, silverton silverton.
# 20.51166534423828
#
# Spanish:      la situación de nuestro hotel le hace un buen punto inicial para descubrir berlin. nuestra dirección física es yorckstr. 83.
# English:      the situation of our hotel makes it a good initial point to discover berlin. our physical address is yorckstr. 83.
# English pred: the situation of our hotel makes a good initial point to discover berlin. our physical direction is yorckstr. 83.
# 32.18218469619751
#
# Spanish:      - ¿ahora quién se ríe?
# English:      - who's laughing now?
# English pred: - who laughs?
# 4.124145746231079
#
# Spanish:      - más vale que tú te agencies otro.
# English:      - you better get a beau of your own.
# English pred: - you better agency another.
# 9.456980466842651
#
# Spanish:      según el banco mundial, las mujeres representan hasta el 70% de los pobres de las zonas rurales y desempeñan un importante papel en las estrategias de supervivencia y la economía de las familias pobres de las zonas rurales.
# English:      according to the world bank, women represent up to 70 per cent of the rural poor and play a major role in the survival strategies and the economy of poor rural households.
# English pred: according to the world bank, women represent up to 70 per cent of rural poor areas and play a major role in survival strategies and the economy of poor families of rural areas.
# 49.366929054260254
